# %% [markdown]
# Haberman Dataset Description:
#
# The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.

# %% [markdown]
# Attribute Information:
#
# 1.Age of patient at time of operation (numerical)
# 2.Patient's year of operation (year - 1900, numerical)
# 3.Number of positive axillary nodes detected (numerical)
# 4.Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

cancer=pd.read_csv('haberman.csv')
#print(cancer)

# %% [markdown]
# # High level Statistics

# %%
#1.Data points
cancer.shape
# Out:
# (306, 4)

# %%
#2.Number of features or column names
print(cancer.columns)
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
#3 number of points for each class
cancer["status"].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %% [markdown]
# 4. Data Points per class
# # 225 are alive ad 81 are expired in the dataset.

# %% [markdown]
# # Objective
# Performing univariate analysis and bi variate analysis to understand which feature i.e 'age', 'year', 'nodes', 'status'
# is more imprtant to determine if the person will die due to cancer or not.

# %%
''' Seeing the above data set we can tell that it is an unbalanced dataset as 225 is one class and 81 are other class'''
# Out:
# ' Seeing the above data set we can tell that it is an unbalanced dataset as 225 is one class and 81 are other class'

# %%
# Univariate analysis
cancer_status1=cancer.loc[cancer['status']==1]
plt.plot(cancer_status1['age'],np.zeros_like(cancer_status1['age']),'o',label='age')
plt.title('univariate for age')
plt.xlabel('age')
plt.ylabel('percentage')

plt.legend()

# %%
sns.FacetGrid(cancer,hue="status",size=5).map(sns.distplot,'age').add_legend()
plt.title('Univariate for age')
plt.xlabel('age')
plt.ylabel('Percentage of people')
# Out:
# C:\Users\Hi\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(11.734296875000005, 0.5, 'Percentage of people')

# %%
sns.FacetGrid(cancer,hue='status',size=5).map(sns.distplot,'year').add_legend()
plt.title('Univariate for year')

plt.ylabel('Percentage of people')
# Out:
# Text(11.112812500000004, 0.5, 'Percentage of people')

# %%
sns.FacetGrid(cancer,hue='status',size=8).map(sns.distplot,'nodes').add_legend()
plt.title('Univariate for nodes')

plt.ylabel('percentage of people')
# Out:
# Text(9.089013671875001, 0.5, 'percentage of people')

# %% [markdown]
# Observations for histograms:
# 1.None of them were useful as none were able to distinguish.

# %%
#plotting pdf and cdf
counts,bin_edges=np.histogram(cancer['age'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)
print(bin_edges)

cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.title('pdf & cdf')
plt.xlabel('age')
plt.ylabel('percentage')
# Out:
# [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]
# Text(0, 0.5, 'percentage')

# %%
counts,bin_edges=np.histogram(cancer['year'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)

cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.title('pdf & cdf')
plt.xlabel('year')
plt.ylabel('percentage')
# Out:
# [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# Text(0, 0.5, 'percentage')

# %%
counts,bin_edges=np.histogram(cancer['nodes'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)

cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.title('pdf & cdf')
plt.xlabel('nodes')
plt.ylabel('percentage')
# Out:
# [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]
# Text(0, 0.5, 'percentage')

# %%
#plotting pdf and cdf
counts,bin_edges=np.histogram(cancer['age'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)
print(bin_edges)

cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

##
counts,bin_edges=np.histogram(cancer['year'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)

cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

##
counts,bin_edges=np.histogram(cancer['nodes'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)

cdf=np.cumsum(pdf)
plt.title('pdf & cdf')
plt.xlabel('age,year,nodes')
plt.ylabel('percentage')
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]
# [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]

# %% [markdown]
# Observations
# 1.If we plot the graph at (36,0). We will be able to distinguish 90 %of status to belong to status 1 or 2 using age.
# But, when it comes to year 10 % of it will be misclassified as 10 % of age coincides with year in the cdf graph.

# %%
#Box plot
sns.boxplot(x='status',y='age', data=cancer)
plt.title('Box plot for status vs age')
plt.show()

# %%
#Box plot
sns.boxplot(x='status',y='year', data=cancer)
plt.title('Box plot for status vs year')
plt.show()

# %%
#Box plot
sns.boxplot(x='status',y='nodes', data=cancer)
plt.title('Box plot for status vs nodes')
plt.show()

# %% [markdown]
#  Observations.
#  1.Looking at the box plot, we can say that nodes compared to the year and age features. Nodes can be compartively better
#  to classify the patients as 1 or 2

# %%
#Violin plot
sns.violinplot(x="status", y="age", data=cancer, size=8)
plt.title('Violin plot for status vs age')
plt.show()

# %%
#Violin plot
sns.violinplot(x="status", y="year", data=cancer, size=8)
plt.title('Violin plot for status vs year')
plt.show()

# %%
#Violin plot
sns.violinplot(x="status", y="nodes", data=cancer, size=8)
plt.title('Violin plot for status vs nodes')
plt.show()

# %% [markdown]
# # Observations:
# 1. We cannot make any sense as there is no way to distinct between status 1 and status 2.

# %%
#Performing bi variate analysis 
# 2.pair plot
sns.set_style('whitegrid')
sns.pairplot(cancer, hue="status",vars=["age", "year", "nodes"], size=3)
plt.title('Pairplot graph for the haberman dataset')
# Out:
# C:\Users\Hi\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Pairplot graph for the haberman dataset')

# %% [markdown]
# ## Observations
# 1. Performing pair plot does not yield any results. As, we can see no two features in the above graph make a distinct seperation between status 1 and 2.
# 2. Hence, bi variate analysis doesnt give us any significant way.
